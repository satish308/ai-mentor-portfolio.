# %% [markdown]
# <a href="https://colab.research.google.com/github/satish308/ai-mentor-portfolio./blob/main/Day10_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# np.float_ was removed in NumPy 2.0

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 54.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 976.4/976.4 kB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.5/111.5 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 57.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 822.5/822.5 kB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 42.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.2/178.2 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 18.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 85.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 38.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 16.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 70.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.8/334.8 kB 18.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 66.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 68.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.1/731.1 kB 32.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.3/122.3 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 21.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.53.0 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-api>=1.35.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# google-adk 1.29.0 requires google-genai<2.0.0,>=1.64.0, but you have google-genai 2.7.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-exporter-otlp-proto-http>=1.36.0, but you have opentelemetry-exporter-otlp-proto-http 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# wandb 0.27.0 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# bigframes 2.40.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 05:24:03 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 05:24:03 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
llm = "gemini/gemini-2.5-flash"

# %% [markdown]
# Runtime → Restart Session

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: de59a9ad-f567-487a-916f-f26f41229293                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: ca278811-2d53-454b-b865-91edf7dbd641                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here is a factual placement brief for TCS Digital preparation for B.Tech students:                             │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │                                                                                                                 │
# │  *   **Online Assessment:** Typically includes sections on quantitative aptitude, logical reasoning, verbal     │
# │  ability, and advanced coding challenges (often 1-2 complex problems).                                          │
# │  *   **Technical Interview:** Focuses on core computer science fundamentals (DSA, OS, DBMS, OOPs), projects,    │
# │  and in-depth knowledge of specialized technical stacks.                                                        │
# │  *   **Managerial Interview:** Evaluates problem-solving skills, leadership potential, project handling         │
# │  experience, and ability to work in teams through scenario-based questions.                                     │
# │  *   **HR Interview:** Assesses cultural fit, communication skills, career aspirations, and understanding of    │
# │  TCS values and work culture.                                                                                   │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │                                                                                                                 │
# │  *   **Cloud Computing:** AWS, Azure, GCP fundamentals, understanding of IaaS, PaaS, SaaS, serverless           │
# │  architectures.                                                                                                 │
# │  *   **Data Science & Machine Learning:** Python/R, ML algorithms, deep learning frameworks (TensorFlow,        │
# │  PyTorch), data manipulation libraries (Pandas, NumPy).                                                         │
# │  *   **Full-stack Development:** Expertise in frameworks like Spring Boot (Java), Django/Flask (Python),        │
# │  Node.js, and front-end technologies (React, Angular, Vue.js).                                                  │
# │  *   **DevOps & Containerization:** Familiarity with tools like Docker, Kubernetes, Jenkins, Git, and CI/CD     │
# │  pipelines.                                                                                                     │
# │  *   **Big Data Technologies:** Concepts of Hadoop, Spark, Kafka, and data streaming/processing.                │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │                                                                                                                 │
# │  *   **Academics:** Usually a minimum of 60% or 6.0 CGPA throughout 10th, 12th, and B.Tech/BE degrees.          │
# │  *   **Branch Specific:** Primarily for B.Tech/BE students from Computer Science, Information Technology,       │
# │  Electronics & Communication, Electrical & Electronics, and related engineering branches.                       │
# │  *   **Year of Graduation:** Typically targeted at final-year students (or pre-final year for internships with  │
# │  PPO potential).                                                                                                │
# │  *   **Backlogs/Gaps:** No active backlogs at the time of application; a maximum of 1-2 years of academic gap   │
# │  might be permissible with valid reasons.                                                                       │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │                                                                                                                 │
# │  *   **Increased Specialization:** Higher demand for candidates with expertise in niche areas like AI/ML,       │
# │  Cybersecurity, IoT, Blockchain, and advanced Cloud solutions.                                                  │
# │  *   **Project-Based Evaluation:** Strong emphasis on practical experience demonstrated through significant     │
# │  projects, often looking for depth over breadth.                                                                │
# │  *   **Higher Compensation:** TCS Digital offers significantly higher compensation packages compared to the     │
# │  TCS Ninja profile, reflecting the advanced skill sets required.                                                │
# │  *   **Focus on Problem Solving:** Interviews increasingly include complex, real-world problem-solving          │
# │  scenarios rather than just theoretical questions.                                                              │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │                                                                                                                 │
# │  *   **Master DSA & Core CS:** Solidify Data Structures and Algorithms. Strengthen fundamentals of Operating    │
# │  Systems, DBMS, Object-Oriented Programming, and Computer Networks.                                             │
# │  *   **Specialize and Build Projects:** Choose 1-2 in-demand technologies (e.g., Python ML with a framework, a  │
# │  full-stack project, or a cloud-native application) and build substantial, deployable projects.                 │
# │  *   **Practice Coding Platforms:** Regularly solve advanced coding problems on platforms like LeetCode,        │
# │  HackerRank, GeeksforGeeks to enhance problem-solving speed and accuracy.                                       │
# │  *   **Strengthen Aptitude:** Practice quantitative aptitude, logical reasoning, and verbal ability             │
# │  rigorously, as the online assessment is a crucial initial filter.                                              │
# │  *   **Behavioral & Communication Skills:** Prepare for common HR and managerial questions. Work on clear,      │
# │  concise communication and articulate your thought process during technical discussions.                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 44b84852-1d9a-4f9a-b398-80bfc0efd27f                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.
# ERROR:crewai.flow.flow:Error executing listener call_llm_and_parse: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are   │
# │  usually temporary. Please try again later.                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_and_parse: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are   │
# │  usually temporary. Please try again later.                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Unlock a world of advanced tech opportunities with TCS Digital! This premium hiring profile seeks the          │
# │  brightest minds with specialized skills and a passion for innovation. Prepare to elevate your career and       │
# │  build the future with a global leader.                                                                         │
# │                                                                                                                 │
# │  ## The Road to TCS Digital: Your Interview Journey                                                             │
# │                                                                                                                 │
# │  The TCS Digital hiring process is rigorous, designed to identify top-tier talent. Be ready for a multi-stage   │
# │  evaluation:                                                                                                    │
# │                                                                                                                 │
# │  *   **Online Assessment (OA):** A critical initial filter, typically covering quantitative aptitude, logical   │
# │  reasoning, verbal ability, and advanced coding challenges (expect 1-2 complex programming problems).           │
# │  *   **Technical Interview:** Deep dive into your core computer science fundamentals (Data Structures &         │
# │  Algorithms, Operating Systems, DBMS, Object-Oriented Programming). Be prepared to discuss your projects in     │
# │  detail and showcase expertise in specific technical stacks.                                                    │
# │  *   **Managerial Interview:** Evaluates your problem-solving capabilities, leadership potential, project       │
# │  handling experience, and ability to collaborate effectively through scenario-based questions.                  │
# │  *   **HR Interview:** Assesses your cultural fit, communication skills, career aspirations, and understanding  │
# │  of TCS values and work culture.                                                                                │
# │                                                                                                                 │
# │  ## Master These Tech Frontiers: Key Skills for Success                                                         │
# │                                                                                                                 │
# │  TCS Digital targets candidates with specialized knowledge in cutting-edge technologies. Focus on developing    │
# │  proficiency in areas like:                                                                                     │
# │                                                                                                                 │
# │  *   **Cloud Computing:** AWS, Azure, GCP fundamentals; understanding IaaS, PaaS, SaaS, and serverless          │
# │  architectures.                                                                                                 │
# │  *   **Data Science & Machine Learning:** Strong in Python/R, ML algorithms, deep learning frameworks           │
# │  (TensorFlow, PyTorch), and data manipulation libraries (Pandas, NumPy).                                        │
# │  *   **Full-stack Development:** Expertise in frameworks such as Spring Boot (Java), Django/Flask (Python),     │
# │  Node.js, alongside front-end technologies (React, Angular, Vue.js).                                            │
# │  *   **DevOps & Containerization:** Familiarity with Docker, Kubernetes, Jenkins, Git, and CI/CD pipelines.     │
# │  *   **Big Data Technologies:** Grasping concepts of Hadoop, Spark, and Kafka for data streaming and            │
# │  processing.                                                                                                    │
# │                                                                                                                 │
# │  ## Are You Ready? Eligibility Criteria                                                                         │
# │                                                                                                                 │
# │  Ensure you meet the foundational requirements to be considered for TCS Digital:                                │
# │                                                                                                                 │
# │  *   **Academics:** A consistent academic record, typically requiring a minimum of 60% or 6.0 CGPA throughout   │
# │  10th, 12th, and B.Tech/BE degrees.                                                                             │
# │  *   **Branch Specific:** Primarily open to B.Tech/BE students from Computer Science, Information Technology,   │
# │  Electronics & Communication, Electrical & Electronics, and other related engineering branches.                 │
# │  *   **Year of Graduation:** Targeted at final-year students, with opportunities for pre-final year students    │
# │  seeking internships with potential PPOs.                                                                       │
# │  *   **Backlogs/Gaps:** No active backlogs at the time of application. A maximum of 1-2 years of academic gap   │
# │  might be permissible with valid, documented reasons.                                                           │
# │                                                                                                                 │
# │  ## What's Hot: Current Hiring Landscape                                                                        │
# │                                                                                                                 │
# │  Stay informed about the latest trends shaping TCS Digital recruitment:                                         │
# │                                                                                                                 │
# │  *   **Increased Specialization:** High demand for candidates with expertise in niche areas like AI/ML,         │
# │  Cybersecurity, IoT, Blockchain, and advanced Cloud solutions.                                                  │
# │  *   **Project-Based Evaluation:** Strong emphasis on practical, hands-on experience demonstrated through       │
# │  significant, deployable projects. Depth over breadth is key.                                                   │
# │  *   **Higher Compensation:** TCS Digital offers significantly more competitive compensation packages compared  │
# │  to the TCS Ninja profile, reflecting the advanced skill sets required.                                         │
# │  *   **Focus on Problem Solving:** Interviews increasingly feature complex, real-world problem-solving          │
# │  scenarios, moving beyond theoretical questions.                                                                │
# │                                                                                                                 │
# │  ## Your Action Plan: Essential Prep Tips                                                                       │
# │                                                                                                                 │
# │  Strategize your preparation for optimal results:                                                               │
# │                                                                                                                 │
# │  *   **Master DSA & Core CS:** Build an unshakeable foundation in Data Structures and Algorithms. Solidify      │
# │  your understanding of Operating Systems, DBMS, Object-Oriented Programming, and Computer Networks.             │
# │  *   **Specialize and Build Projects:** Choose 1-2 in-demand technologies (e.g., Python ML with a framework, a  │
# │  robust full-stack application, or a cloud-native solution) and develop substantial, well-documented projects.  │
# │  *   **Practice Coding Platforms:** Regularly solve advanced coding problems on platforms like LeetCode,        │
# │  HackerRank, and GeeksforGeeks to improve your problem-solving speed, accuracy, and logic.                      │
# │  *   **Strengthen Aptitude:** Dedicate time to rigorously practice quantitative aptitude, logical reasoning,    │
# │  and verbal ability, as the online assessment is a crucial initial hurdle.                                      │
# │  *   **Behavioral & Communication Skills:** Prepare for common HR and managerial questions. Work on clearly     │
# │  articulating your thoughts and technical solutions during discussions.                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  TCS Digital offers a pathway to impactful roles at the forefront of technology. Begin your focused             │
# │  preparation today, showcase your specialized skills, and seize this opportunity to accelerate your career.     │
# │  Good luck!                                                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Unlock a world of advanced tech opportunities with TCS Digital! This premium hiring profile seeks the brightest minds with specialized skills and a passion for innovation. Prepare to elevate your career and build the future with a global leader.
#
# ## The Road to TCS Digital: Your Interview Journey
#
# The TCS Digital hiring process is rigorous, designed to identify top-tier talent. Be ready for a multi-stage evaluation:
#
# *   **Online Assessment (OA):** A critical initial filter, typically covering quantitative aptitude, logical reasoning, verbal ability, and advanced coding challenges (expect 1-2 complex programming problems).
# *   **Technical Interview:** Deep dive into your core computer science fundamentals (Data Structures & Algorithms, Operating Systems, DBMS, Object-Oriented Programming). Be prepared to discuss your projects in detail and showcase expertise in specific technical stacks.
# *   **Managerial Interview:** Evaluates your problem-solving capabilities, leadership potential, project handling experience, and ability to collaborate effectively through scenario-based questions.
# *   **HR Interview:** Assesses your cultural fit, communication skills, career aspirations, and understanding of TCS values and work culture.
#
# ## Master These Tech Frontiers: Key Skills for Success
#
# TCS Digital targets candidates with specialized knowledge in cutting-edge technologies. Focus on developing proficiency in areas like:
#
# *   **Cloud Computing:** AWS, Azure, GCP fundamentals; understanding IaaS, PaaS, SaaS, and serverless architectures.
# *   **Data Science & Machine Learning:** Strong in Python/R, ML algorithms, deep learning frameworks (TensorFlow, PyTorch), and data manipulation libraries (Pandas, NumPy).
# *   **Full-stack Development:** Expertise in frameworks such as Spring Boot (Java), Django/Flask (Python), Node.js, alongside front-end technologies (React, Angular, Vue.js).
# *   **DevOps & Containerization:** Familiarity with Docker, Kubernetes, Jenkins, Git, and CI/CD pipelines.
# *   **Big Data Technologies:** Grasping concepts of Hadoop, Spark, and Kafka for data streaming and processing.
#
# ## Are You Ready? Eligibility Criteria
#
# Ensure you meet the foundational requirements to be considered for TCS Digital:
#
# *   **Academics:** A consistent academic record, typically requiring a minimum of 60% or 6.0 CGPA throughout 10th, 12th, and B.Tech/BE degrees.
# *   **Branch Specific:** Primarily open to B.Tech/BE students from Computer Science, Information Technology, Electronics & Communication, Electrical & Electronics, and other related engineering branches.
# *   **Year of Graduation:** Targeted at final-year students, with opportunities for pre-final year students seeking internships with potential PPOs.
# *   **Backlogs/Gaps:** No active backlogs at the time of application. A maximum of 1-2 years of academic gap might be permissible with valid, documented reasons.
#
# ## What's Hot: Current Hiring Landscape
#
# Stay informed about the latest trends shaping TCS Digital recruitment:
#
# *   **Increased Specialization:** High demand for candidates with expertise in niche areas like AI/ML, Cybersecurity, IoT, Blockchain, and advanced Cloud solutions.
# *   **Project-Based Evaluation:** Strong emphasis on practical, hands-on experience demonstrated through significant, deployable projects. Depth over breadth is key.
# *   **Higher Compensation:** TCS Digital offers significantly more competitive compensation packages compared to the TCS Ninja profile, reflecting the advanced skill sets required.
# *   **Focus on Problem Solving:** Interviews increasingly feature complex, real-world problem-solving scenarios, moving beyond theoretical questions.
#
# ## Your Action Plan: Essential Prep Tips
#
# Strategize your preparation for optimal results:
#
# *   **Master DSA & Core CS:** Build an unshakeable foundation in Data Structures and Algorithms. Solidify your understanding of Operating Systems, DBMS, Object-Oriented Programming, and Computer Networks.
# *   **Specialize and Build Projects:** Choose 1-2 in-demand technologies (e.g., Python ML with a framework, a robust full-stack application, or a cloud-native solution) and develop substantial, well-documented projects.
# *   **Practice Coding Platforms:** Regularly solve advanced coding problems on platforms like LeetCode, HackerRank, and GeeksforGeeks to improve your problem-solving speed, accuracy, and logic.
# *   **Strengthen Aptitude:** Dedicate time to rigorously practice quantitative aptitude, logical reasoning, and verbal ability, as the online assessment is a crucial initial hurdle.
# *   **Behavioral & Communication Skills:** Prepare for common HR and managerial questions. Work on clearly articulating your thoughts and technical solutions during discussions.
#
# ---
#
# TCS Digital offers a pathway to impactful roles at the forefront of technology. Begin your focused preparation today, showcase your specialized skills, and seize this opportunity to accelerate your career. Good luck!

# %%
await crew.kickoff_async()
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: de59a9ad-f567-487a-916f-f26f41229293                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: ca278811-2d53-454b-b865-91edf7dbd641                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here's a placement brief for TCS Digital preparation for B.Tech students:                                      │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │  *   **Online Aptitude Test:** Assesses verbal ability, logical reasoning, and numerical ability, typically     │
# │  featuring moderate difficulty questions.                                                                       │
# │  *   **Online Coding Test:** Consists of 1-2 coding problems that require good problem-solving skills, often    │
# │  allowing choice of programming language.                                                                       │
# │  *   **Technical Interview (TR):** Focuses on Data Structures & Algorithms (DSA), core CS subjects (OS, DBMS,   │
# │  OOPS), and in-depth discussion of projects and chosen programming language.                                    │
# │  *   **Managerial Interview (MR):** Evaluates problem-solving approach, teamwork, leadership potential, and     │
# │  sometimes advanced technical concepts or domain knowledge.                                                     │
# │  *   **HR Interview:** Covers career aspirations, salary expectations, company fit, and general background      │
# │  verification.                                                                                                  │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │  *   **Core Programming Languages:** Strong proficiency in at least one language like Java, Python, C++, or     │
# │  C#, with solid Object-Oriented Programming (OOP) concepts.                                                     │
# │  *   **Web Technologies:** Familiarity with front-end development (HTML, CSS, JavaScript, React/Angular)        │
# │  and/or back-end frameworks (Spring Boot, Node.js, Django).                                                     │
# │  *   **Databases:** Understanding of SQL (e.g., MySQL, PostgreSQL) and basic concepts of NoSQL databases.       │
# │  *   **Core CS Concepts:** Sound knowledge of Data Structures & Algorithms, Operating Systems, Database         │
# │  Management Systems, and Computer Networks.                                                                     │
# │  *   **Cloud & DevOps (Advantageous):** Exposure to cloud platforms (AWS/Azure/GCP), version control (Git),     │
# │  and CI/CD principles.                                                                                          │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │  *   **Degree:** B.Tech/BE in Computer Science, Information Technology, Electronics & Communication             │
# │  Engineering, Electrical Engineering, or related technical branches.                                            │
# │  *   **Academic Performance:** Consistent academic record (10th, 12th, Graduation) with typically 60% or 6.0    │
# │  CGPA throughout. Some drives might have higher cutoffs for Digital roles.                                      │
# │  *   **Backlogs:** Generally, no active backlogs are allowed at the time of application or joining; limited     │
# │  academic gaps are usually permissible.                                                                         │
# │  *   **Year of Passing:** Specific to the recruitment drive, usually targeting recent graduates or final-year   │
# │  students.                                                                                                      │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │  *   **Emphasis on Problem-Solving:** Higher weightage is given to candidates demonstrating strong Data         │
# │  Structures & Algorithms and competitive programming skills.                                                    │
# │  *   **Cloud & DevOps Acumen:** Growing demand for candidates familiar with cloud platforms, microservices      │
# │  architecture, and modern DevOps practices.                                                                     │
# │  *   **Full-Stack & Project Experience:** Preference for candidates with hands-on projects showcasing           │
# │  full-stack capabilities or deep expertise in a specific technical domain.                                      │
# │  *   **Digital Competency:** Assessment of innovative thinking, adaptability to new technologies, and           │
# │  readiness for emerging areas like AI/ML or Blockchain.                                                         │
# │  *   **Communication Skills:** Strong emphasis on clear articulation of technical concepts, project details,    │
# │  and problem-solving approaches during interviews.                                                              │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │  *   **Master DSA & Core CS:** Dedicate significant time to practicing Data Structures, Algorithms, and         │
# │  thoroughly revise core Computer Science subjects (OS, DBMS, OOPS).                                             │
# │  *   **Hands-on Project Development:** Build 2-3 substantial projects using relevant modern technologies to     │
# │  showcase practical skills and problem-solving abilities.                                                       │
# │  *   **Proficiency in One Language:** Become highly proficient in at least one programming language             │
# │  (Java/Python/C++) with strong OOPS implementation.                                                             │
# │  *   **Practice Coding Platforms:** Regularly solve problems on platforms like LeetCode, HackerRank,            │
# │  GeeksforGeeks to improve coding speed and accuracy.                                                            │
# │  *   **Mock Interviews & Behavioral Prep:** Practice technical and HR interview questions, focusing on          │
# │  explaining projects, thought processes, and behavioral responses.                                              │
# │  *   **Stay Updated with Tech:** Keep abreast of recent advancements in cloud computing, AI/ML, software        │
# │  development methodologies, and industry best practices.                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 44b84852-1d9a-4f9a-b398-80bfc0efd27f                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Are you ready to innovate at the forefront of technology and secure a premium role with a global leader? TCS   │
# │  Digital offers B.Tech students an exceptional opportunity to build a career at the cutting edge. Prepare to    │
# │  unlock your potential and join a team that's shaping the future!                                               │
# │                                                                                                                 │
# │  ### 1. Hiring Process                                                                                          │
# │  The TCS Digital selection journey is comprehensive, designed to identify top talent. Here’s what to expect:    │
# │                                                                                                                 │
# │  *   **Online Aptitude Test:** Measures verbal, logical, and numerical abilities. Focus on moderate difficulty  │
# │  questions.                                                                                                     │
# │  *   **Online Coding Test:** Solve 1-2 coding problems, showcasing problem-solving skills in your preferred     │
# │  language.                                                                                                      │
# │  *   **Technical Interview (TR):** In-depth discussion on Data Structures & Algorithms (DSA), core CS subjects  │
# │  (OS, DBMS, OOPS), projects, and chosen programming language.                                                   │
# │  *   **Managerial Interview (MR):** Evaluates problem-solving approach, teamwork, leadership potential, and     │
# │  sometimes advanced technical concepts.                                                                         │
# │  *   **HR Interview:** Covers career aspirations, salary expectations, company fit, and background              │
# │  verification.                                                                                                  │
# │                                                                                                                 │
# │  ### 2. Technical Stack                                                                                         │
# │  To excel in TCS Digital, a strong foundation in these areas is crucial:                                        │
# │                                                                                                                 │
# │  *   **Core Programming Languages:** Master at least one (Java, Python, C++, C#) with solid Object-Oriented     │
# │  Programming (OOP) concepts.                                                                                    │
# │  *   **Web Technologies:** Familiarity with front-end (HTML, CSS, JavaScript, React/Angular) and/or back-end    │
# │  (Spring Boot, Node.js, Django) frameworks is a plus.                                                           │
# │  *   **Databases:** Strong understanding of SQL (MySQL, PostgreSQL) and basic NoSQL concepts.                   │
# │  *   **Core CS Concepts:** Proficient knowledge of Data Structures & Algorithms, Operating Systems, DBMS, and   │
# │  Computer Networks.                                                                                             │
# │  *   **Cloud & DevOps (Advantage):** Exposure to cloud platforms (AWS/Azure/GCP), Git, and CI/CD principles.    │
# │                                                                                                                 │
# │  ### 3. Eligibility                                                                                             │
# │  Ensure you meet the academic criteria to be considered for TCS Digital:                                        │
# │                                                                                                                 │
# │  *   **Degree:** B.Tech/BE in CS, IT, ECE, EE, or related technical branches.                                   │
# │  *   **Academic Performance:** Consistent 60% or 6.0 CGPA throughout 10th, 12th, and Graduation. Note: Digital  │
# │  roles may have higher cutoffs.                                                                                 │
# │  *   **Backlogs:** Generally, no active backlogs allowed at the time of application or joining; limited         │
# │  academic gaps are usually permissible.                                                                         │
# │  *   **Year of Passing:** Typically targets recent graduates or final-year students, specific to the            │
# │  recruitment drive.                                                                                             │
# │                                                                                                                 │
# │  ### 4. Recent Hiring Trends                                                                                    │
# │  Stay ahead by aligning your preparation with what TCS Digital is currently prioritizing:                       │
# │                                                                                                                 │
# │  *   **Emphasis on Problem-Solving:** High weightage on strong DSA and competitive programming skills.          │
# │  *   **Cloud & DevOps Acumen:** Growing demand for familiarity with cloud platforms, microservices, and modern  │
# │  DevOps practices.                                                                                              │
# │  *   **Full-Stack & Project Experience:** Preference for candidates with hands-on projects showcasing           │
# │  full-stack capabilities or deep domain expertise.                                                              │
# │  *   **Digital Competency:** Assessment of innovative thinking, adaptability to new technologies, and           │
# │  readiness for emerging areas like AI/ML or Blockchain.                                                         │
# │  *   **Communication Skills:** Strong emphasis on clear articulation of technical concepts and problem-solving  │
# │  approaches during interviews.                                                                                  │
# │                                                                                                                 │
# │  ### 5. Prep Tips                                                                                               │
# │  Strategize your preparation for success with these actionable tips:                                            │
# │                                                                                                                 │
# │  *   **Master DSA & Core CS:** Dedicate significant time to practicing Data Structures, Algorithms, and         │
# │  thoroughly revising core Computer Science subjects (OS, DBMS, OOPS).                                           │
# │  *   **Hands-on Project Development:** Build 2-3 substantial projects using modern technologies to demonstrate  │
# │  practical skills and problem-solving.                                                                          │
# │  *   **Proficiency in One Language:** Become highly proficient in at least one programming language             │
# │  (Java/Python/C++) with strong OOPS implementation.                                                             │
# │  *   **Practice Coding Platforms:** Regularly solve problems on platforms like LeetCode, HackerRank,            │
# │  GeeksforGeeks to improve coding speed and accuracy.                                                            │
# │  *   **Mock Interviews & Behavioral Prep:** Practice technical and HR interview questions, focusing on          │
# │  explaining projects, thought processes, and behavioral responses.                                              │
# │  *   **Stay Updated with Tech:** Keep abreast of recent advancements in cloud computing, AI/ML, software        │
# │  development methodologies, and industry best practices.                                                        │
# │                                                                                                                 │
# │  TCS Digital is your launchpad for a future-proof career, offering unparalleled growth in the tech domain.      │
# │  Embrace this challenge, dedicate yourself to preparation, and secure your spot among the tech elite. Your      │
# │  journey starts now!                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw="# TCS Digital — Placement Prep Brief\n\nAre you ready to innovate at the forefront of technology and secure a premium role with a global leader? TCS Digital offers B.Tech students an exceptional opportunity to build a career at the cutting edge. Prepare to unlock your potential and join a team that's shaping the future!\n\n### 1. Hiring Process\nThe TCS Digital selection journey is comprehensive, designed to identify top talent. Here’s what to expect:\n\n*   **Online Aptitude Test:** Measures verbal, logical, and numerical abilities. Focus on moderate difficulty questions.\n*   **Online Coding Test:** Solve 1-2 coding problems, showcasing problem-solving skills in your preferred language.\n*   **Technical Interview (TR):** In-depth discussion on Data Structures & Algorithms (DSA), core CS subjects (OS, DBMS, OOPS), projects, and chosen programming language.\n*   **Managerial Interview (MR):** Evaluates problem-solving approach, teamwork, leadership potential, and sometimes advanced technical concepts.\n*   **HR Interview:** Covers career aspirations, salary expectations, company fit, and background verification.\n\n### 2. Technical Stack\nTo excel in TCS Digital, a strong foundation in these areas is crucial:\n\n*   **Core Programming Languages:** Master at least one (Java, Python, C++, C#) with solid Object-Oriented Programming (OOP) concepts.\n*   **Web Technologies:** Familiarity with front-end (HTML, CSS, JavaScript, React/Angular) and/or back-end (Spring Boot, Node.js, Django) frameworks is a plus.\n*   **Databases:** Strong understanding of SQL (MySQL, PostgreSQL) and basic NoSQL concepts.\n*   **Core CS Concepts:** Proficient knowledge of Data Structures & Algorithms, Operating Systems, DBMS, and Computer Networks.\n*   **Cloud & DevOps (Advantage):** Exposure to cloud platforms (AWS/Azure/GCP), Git, and CI/CD principles.\n\n### 3. Eligibility\nEnsure you meet the academic criteria to be considered for TCS Digital:\n\n*   **Degree:** B.Tech/BE in CS, IT, ECE, EE, or related technical branches.\n*   **Academic Performance:** Consistent 60% or 6.0 CGPA throughout 10th, 12th, and Graduation. Note: Digital roles may have higher cutoffs.\n*   **Backlogs:** Generally, no active backlogs allowed at the time of application or joining; limited academic gaps are usually permissible.\n*   **Year of Passing:** Typically targets recent graduates or final-year students, specific to the recruitment drive.\n\n### 4. Recent Hiring Trends\nStay ahead by aligning your preparation with what TCS Digital is currently prioritizing:\n\n*   **Emphasis on Problem-Solving:** High weightage on strong DSA and competitive programming skills.\n*   **Cloud & DevOps Acumen:** Growing demand for familiarity with cloud platforms, microservices, and modern DevOps practices.\n*   **Full-Stack & Project Experience:** Preference for candidates with hands-on projects showcasing full-stack capabilities or deep domain expertise.\n*   **Digital Competency:** Assessment of innovative thinking, adaptability to new technologies, and readiness for emerging areas like AI/ML or Blockchain.\n*   **Communication Skills:** Strong emphasis on clear articulation of technical concepts and problem-solving approaches during interviews.\n\n### 5. Prep Tips\nStrategize your preparation for success with these actionable tips:\n\n*   **Master DSA & Core CS:** Dedicate significant time to practicing Data Structures, Algorithms, and thoroughly revising core Computer Science subjects (OS, DBMS, OOPS).\n*   **Hands-on Project Development:** Build 2-3 substantial projects using modern technologies to demonstrate practical skills and problem-solving.\n*   **Proficiency in One Language:** Become highly proficient in at least one programming language (Java/Python/C++) with strong OOPS implementation.\n*   **Practice Coding Platforms:** Regularly solve problems on platforms like LeetCode, HackerRank, GeeksforGeeks to improve coding speed and accuracy.\n*   **Mock Interview ...

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 5008

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here is a factual placement brief for TCS Digital preparation for B.Tech students:
#
# ### Hiring Process
#
# *   **Online Assessment:** Typically includes sections on quantitative aptitude, logical reasoning, verbal ability, and advanced coding challenges (often 1-2 complex problems).
# *   **Technical Interview:** Focuses on core computer science fundamentals (DSA, OS, DBMS, OOPs), projects, and in-depth knowledge of specialized technical stacks.
# *   **Managerial Interview:** Evaluates problem-solving skills, leadership potential, project handling experience, and ability to work in teams through scenario-based questions.
# *   **HR Interview:** Assesses cultural fit, communication skills, career aspirations, and understanding of TCS values and work culture.
#
# ### Technical Stack
#
# *   **Cloud Comput
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Unlock a world of advanced tech opportunities with TCS Digital! This premium hiring profile seeks the brightest minds with specialized skills and a passion for innovation. Prepare to elevate your career and build the future with a global leader.
#
# ## The Road to TCS Digital: Your Interview Journey
#
# The TCS Digital hiring process is rigorous, designed to identify top-tier talent. Be ready for a multi-stage evaluation:
#
# *   **Online Assessment (OA):** A critical initial filter, typically covering quantitative aptitude, logical reasoning, verbal ability, and advanced coding challenges (expect 1-2 complex programming problems).
# *   **Technical Interview:** Deep dive into your core computer science fundamentals (Data Structures & Algorithms, Operating System

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Unlock a world of advanced tech opportunities with TCS Digital! This premium hiring profile seeks the brightest minds with specialized skills and a passion for innovation. Prepare to elevate your career and build the future with a global leader.
#
# ## The Road to TCS Digital: Your Interview Journey
#
# The TCS Digital hiring process is rigorous, designed to identify top-tier talent. Be ready for a multi-stage evaluation:
#
# *   **Online Assessment (OA):** A critical initial filter, typically covering quantitative aptitude, logical reasoning, verbal ability, and advanced coding challenges (expect 1-2 complex programming problems).
# *   **Technical Interview:** Deep dive into your core computer science fundamentals (Data Structures & Algorithms, Operating Systems, DBMS, Object-Oriented Programming). Be prepared to discuss your projects in detail and showcase expertise in specific technical stacks.
# *   **Managerial Interview:** Evaluates your problem-solving capabilities, leadership potential, project handling experience, and ability to collaborate effectively through scenario-based questions.
# *   **HR Interview:** Assesses your cultural fit, communication skills, career aspirations, and understanding of TCS values and work culture.
#
# ## Master These Tech Frontiers: Key Skills for Success
#
# TCS Digital targets candidates with specialized knowledge in cutting-edge technologies. Focus on developing proficiency in areas like:
#
# *   **Cloud Computing:** AWS, Azure, GCP fundamentals; understanding IaaS, PaaS, SaaS, and serverless architectures.
# *   **Data Science & Machine Learning:** Strong in Python/R, ML algorithms, deep learning frameworks (TensorFlow, PyTorch), and data manipulation libraries (Pandas, NumPy).
# *   **Full-stack Development:** Expertise in frameworks such as Spring Boot (Java), Django/Flask (Python), Node.js, alongside front-end technologies (React, Angular, Vue.js).
# *   **DevOps & Containerization:** Familiarity with Docker, Ku
